# %% [markdown]
# #### CS164 Preclass Work for Session 3.2
#
# ### Basics of Real Analysis 5: Sublevel Sets and Coercive Functions
# _Yoav Rabinovich, Jan 20_
#
# -----------------------------

# %% [markdown]
# **(1)** *For each of the functions below, plot a diagram of their level sets and determine whether or not the functions are coercive. You may use a graphical package to plot the level sets.*
#
# $\textbf{(a)} f(x,y) = x+y$
#
# $\textbf{(b)} f(x,y) = x^2+4y^2$
#
# $\textbf{(c)} f(x,y) = xy$
#
# $\textbf{(d)} f(x,y) = x^2-y^2$
#
# $\textbf{(e)} f(x,y) = x^2+2xy+y^2$
#
# $\textbf{(f)} f(x,y) = x^4+2xy+y^4$
#
# **(b)** and **(f)** are coercive, since for any direction, as the norm approaches infinity so does the image.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline

# %%
x, y = np.meshgrid(np.linspace(-10,10,100), np.linspace(-10,10,100))

a = x+y
b = x**2+4*y**2
c = x*y
d = x**2-y**2
e = x**2+2*x*y+y**2
f = x**4+2*x*y+y**4

arr = [a,b,c,d,e,f]

fig = plt.figure(figsize=(18,18))
for i in range(6):
    ax = fig.add_subplot(4,3,i+1,projection='3d')
    ax2 = fig.add_subplot(4,3,i+7)
    ax.contour3D(x,y,arr[i],50)
    ax2.contour(x,y,arr[i],50)

plt.show()

# %% [markdown]
# **(2)** *Prove that the following function is coercive and describe its sublevel sets mathematically (no need to plot them).*
#
# $$f(x,y,z) = e^{x^2+y^2+z^2}$$
#
# Since $f(\vec{x})= e^{x^2+y^2+z^2} = e^{||\vec{x}||^2}$, for any sequence of coordinates $\{\vec{x}_k\}$, as $||\vec{x}||\rightarrow +\infty$, $f(x)\rightarrow +\infty$.
#
# **Realized mid-class that I forgot to address second part, completing:**
#
# The sublevels can be described by equating the function to a constant:
#
# $$e^{||\vec{x}||^2}=\alpha$$
#
# $$||\vec{x}||^2 = log{\alpha}$$
#
# Then the sublevels are $\{(x,y,z)|x^2+y^2+z^2=\log{\alpha} \ \text{for} \ \alpha \in \mathbb{R}\}$
